# %%
import numpy as np
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
def graphLine(slope, intercept):
    plt.scatter(X,y)
    axes = plt.gca()
    x_vals = np.array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, c="red")

# %%
X = 2 * np.random.rand(200, 1)
y = 1.2 * X + 1 + 0.8 * np.random.randn(200, 1)
X_ = sm.add_constant(X)  # add constant for intercept computation
plt.scatter(X,y)

# %%
print('Method 1: matrix formulation')
method1 = np.dot(np.linalg.inv(np.dot(X_.T, X_)), np.dot(X_.T, y))
print(method1)
graphLine(method1[0], 0)
# Out:
# Method 1: matrix formulation
# [[1.12390955]
#  [1.11504191]]

# %%
# statsmodels lib
model = sm.OLS(y, X_).fit()
print('Method 2: statsmodels')
print(f'{model.params}')
graphLine(model.params, 0)
# Out:
# Method 2: statsmodels
# [1.12390955 1.11504191]

# %%
# LinearRegression
print('Method 3: sklearn.linear_model.LinearRegression')
lr_model = LinearRegression(fit_intercept=True)
lr_model.fit(X, y)
print(lr_model.coef_)
print(f'Intercept: {lr_model.intercept_}, coeff: {lr_model.coef_}')
graphLine(lr_model.coef_[0], lr_model.intercept_)
# Out:
# Method 3: sklearn.linear_model.LinearRegression
# [[1.11504191]]
# Intercept: [1.12390955], coeff: [[1.11504191]]
